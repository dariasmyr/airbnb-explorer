# %% [markdown]
# # Project Description: Airbnb Explorer
# <p align="center">
#   <a href="http://localhost:3000/" target="blank"><img src="New_York_City_.png" width="400" alt="New_York_City" /></a>
# </p>
#
# ## Overview
# The Airbnb Explorer project aims to provide users with insights into Airbnb listings in New York City. By analyzing data on Airbnb listings, this project helps users find the perfect rental for their needs.

# %% [markdown]
# ## Price
# ### Mean Price
# The price of a rental is one of the most important factors when choosing a rental. The price of a rental can vary greatly depending on the location, amenities, and size of the rental. The following graph shows the mean price of rentals in each neighborhood:

# %%
from modules.stats_advanced import Metrics
from modules.database_repository import Database

def connect_to_database():
    db = Database("sqlite+pysqlite:///:/../data/data.sqlite3")
    db.connect()

def get_metrics():
    metrics = Metrics()
    metrics.mean_price_per_heighbourhood()

connect_to_database()
get_metrics()
# Out:
# Connected to database.
# Connected to database.
# 2023-03-02 01:59:58,336 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 01:59:58,336 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,336 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,337 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 01:59:58,337 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,338 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,338 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,339 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 01:59:58,339 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,340 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 01:59:58,340 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,340 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,341 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,341 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:58,341 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,342 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:58,342 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,342 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,343 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,343 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:58,343 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,344 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:58,344 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,344 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,344 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,345 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,345 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,347 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 01:59:58,347 INFO sqlalchemy.engine.Engine [generated in 0.00028s] ()

# %% [markdown]
# ### Price Correlation
# The following graph shows the correlation between the price of a several features of a rental.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.correlation_with_price()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 01:59:58,694 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 01:59:58,694 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,694 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,695 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 01:59:58,696 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,696 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,696 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,697 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 01:59:58,697 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,699 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 01:59:58,699 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,700 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,700 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,701 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:58,701 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,702 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:58,702 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,703 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,703 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,704 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:58,704 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,705 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:58,705 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,706 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:58,706 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:58,707 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:58,707 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:58,710 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 01:59:58,711 INFO sqlalchemy.engine.Engine [generated in 0.00046s] ()

# %%
def get_metrics():
    metrics = Metrics()
    metrics.heatmap_correlation()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 01:59:59,183 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 01:59:59,183 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,184 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,185 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 01:59:59,185 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,186 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,186 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,187 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 01:59:59,187 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,188 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 01:59:59,188 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,189 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,189 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,190 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:59,190 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,191 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:59,191 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,192 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,192 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,193 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:59,193 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,194 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:59,194 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,195 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,195 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,196 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,196 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,198 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 01:59:59,199 INFO sqlalchemy.engine.Engine [generated in 0.00037s] ()

# %% [markdown]
# ## Conveniences
# ### Room Type
# The following graph shows the number of rentals of each type in each neighborhood.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.most_common_room_type()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 01:59:59,567 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 01:59:59,567 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,567 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,568 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 01:59:59,569 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,569 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,570 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,570 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 01:59:59,571 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,571 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 01:59:59,571 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,572 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,572 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,573 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:59,573 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,574 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:59,574 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,574 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,574 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,575 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 01:59:59,576 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,576 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 01:59:59,576 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,576 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 01:59:59,577 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 01:59:59,577 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 01:59:59,577 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 01:59:59,579 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 01:59:59,579 INFO sqlalchemy.engine.Engine [generated in 0.00026s] ()

# %% [markdown]
# ### Reviews
# The following info shows the average number of reviews per month for each neighborhood.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.avg_number_of_reviews_per_month()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 02:00:00,007 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 02:00:00,007 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,008 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,008 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 02:00:00,009 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,009 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,010 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,010 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 02:00:00,011 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,011 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 02:00:00,012 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,012 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,013 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,013 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,014 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,015 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,015 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,015 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,016 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,017 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,017 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,018 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,018 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,019 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,019 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,020 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,021 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,023 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 02:00:00,024 INFO sqlalchemy.engine.Engine [generated in 0.00048s] ()
# Average number of reviews for listings per month in each neighbourhood group:
# neighbourhood_group
# Queens           1.94
# Staten Island    1.87
# Bronx            1.84
# Brooklyn         1.28
# Manhattan        1.27
# Name: reviews_per_month, dtype: object

# %% [markdown]
# ### Duration of Stay
# The following info shows the percentage of rentals that are rented for a certain number of days. Lets say that your preferred duration of stay is +10 days.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.percentage_of_available_listings_from()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 02:00:00,296 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 02:00:00,297 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,297 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,298 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 02:00:00,298 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,299 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,299 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,300 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 02:00:00,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,300 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 02:00:00,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,301 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,301 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,302 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,302 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,302 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,303 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,303 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,303 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,304 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,304 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,305 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,305 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,305 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,305 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,306 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,306 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,308 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 02:00:00,308 INFO sqlalchemy.engine.Engine [generated in 0.00034s] ()

# %% [markdown]
# ## Hosts
# ### Unique Hosts
# The following info shows the number of unique hosts in each neighborhood.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.unique_host_count()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 02:00:00,716 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 02:00:00,716 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,716 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,717 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 02:00:00,718 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,718 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,719 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,719 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 02:00:00,720 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,720 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 02:00:00,721 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,721 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,722 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,722 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,723 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,723 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,723 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,724 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,725 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,725 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:00,726 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,726 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:00,727 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,728 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:00,729 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:00,729 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:00,729 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:00,732 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 02:00:00,732 INFO sqlalchemy.engine.Engine [generated in 0.00047s] ()
# Number of unique hosts in each neighbourhood group:

# %% [markdown]
# ### Hosts with Multiple Listings
# The following info shows the names of hosts that have +10 listings in each neighborhood.

# %%
def get_metrics():
    metrics = Metrics()
    metrics.hosts_with_multiple_listings()

get_metrics()
# Out:
# Connected to database.
# 2023-03-02 02:00:01,122 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-03-02 02:00:01,122 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:01,123 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,124 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("Listings")
# 2023-03-02 02:00:01,124 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,125 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:01,125 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:01,126 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("Listings")
# 2023-03-02 02:00:01,126 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,127 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("Listings")
# 2023-03-02 02:00:01,127 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,128 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:01,128 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:01,129 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:01,129 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,130 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:01,130 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,131 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:01,131 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,132 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("Listings")
# 2023-03-02 02:00:01,133 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,133 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("Listings")
# 2023-03-02 02:00:01,133 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,134 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Listings")
# 2023-03-02 02:00:01,135 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-03-02 02:00:01,135 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-03-02 02:00:01,136 INFO sqlalchemy.engine.Engine [raw sql] ('Listings',)
# 2023-03-02 02:00:01,138 INFO sqlalchemy.engine.Engine SELECT "Listings".id, "Listings".name, "Listings".host_id, "Listings".host_name, "Listings".neighbourhood_group, "Listings".neighbourhood, "Listings".latitude, "Listings".longitude, "Listings".room_type, "Listings".price, "Listings".minimum_nights, "Listings".number_of_reviews, "Listings".last_review, "Listings".reviews_per_month, "Listings".calculated_host_listings_count, "Listings".availability_365
# FROM "Listings"
# 2023-03-02 02:00:01,138 INFO sqlalchemy.engine.Engine [generated in 0.00040s] ()
# Number of hosts with multiple listings in each neighbourhood group:
